# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
access_token = "806766129787981824-ALrgathHdFgVXr61GDdzKPn4Bul18L8"
access_token_secret = "L5TORs4X2j1hzmqk1UtkqrrbxW6yxcP7p3m4mPTQ4COTm"
consumer_key = "fQGFgC4FE6DMQmXe7wNdO8Nph"
consumer_secret = "rOOsvpnVTTOR8916wOENQkkJFo9DVR41t0cnkpXgxgk5ZEzR3h"

# %%
import tweepy
import csv

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
class StreamListener(tweepy.StreamListener):
    def on_status(self, status):
        if not 'RT @' in status.text:
            try:
                csvFile = open('saved_models/streamedtweets.csv', 'a')
                csvWriter = csv.writer(csvFile)
                csvWriter.writerow([status.text])
                csvFile.close()
            except Exception as e:
                print(e)
                pass
            print(status.text)
    def on_error(self, status_code):
        if status_code == 420:
            return False

# %%
stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["fire","ablaze","accident","bleeding","crashed","death","dead","destroyed","disaster","emergency","suicide"],languages=['en'])
# Out:
# This is sensible.
# if Riot can get a beta out before Overwatch 2, Overwatch is dead. 100% no doubt in my mind. The devs clearly have n… https://t.co/AkBToSqUBi
# Enter to #Win in the Death and Betrayal by @SeeleyJamesAuth #VBT at @partnersincr1me !! https://t.co/Vk7JGgsKME
# @KassyDillon I disagree. Buttigieg  is a disaster. Grossly unprepared . From mayor to President . Is this a bad joke or what ?
# Want to work at Baptist Emergency Hospital? We're hiring in #SanAntonio, TX! Click for details: https://t.co/Coq0dz7HmR #Nurse
# @_kimmyeatworld I feel bad blocking people too till u forget about them 🤭 but dead ass can’t afford any more distractions
# @WolfiezGG Fr especially in comp epic some brain dead shi heads
# So sad!!! We All knew it was never suicide anyway! 😥😥😡😡
# Will I ever emerge from this self-imposed Shell? I doubt it. Not fully. That Woman was destroyed. For Fun.
# First day of the semester and I already laughed in the face of my new teacher 💀 I’m dead dead
# ...
